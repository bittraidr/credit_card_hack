# %% [markdown]
# # Visual Data Analysis of Fraudulent Transactions
#
# Your CFO has also requested detailed trends data on specific card holders. Use the starter notebook to query your database and generate visualizations that supply the requested information as follows, then add your visualizations and observations to your markdown report.

# %%
# Initial imports
import pandas as pd
import calendar
import hvplot.pandas
from sqlalchemy import create_engine
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Create a connection to the database
engine = create_engine("postgresql://postgres:postgres@localhost:5432/Challenge_7")

# %%
check_connect = engine.execute("SELECT 1")
print("Connection successful!")
# Out:
# Connection successful!

# %% [markdown]
# ## Data Analysis Question 1
#
# The two most important customers of the firm may have been hacked. Verify if there are any fraudulent transactions in their history. For privacy reasons, you only know that their cardholder IDs are 2 and 18.
#
# * Using hvPlot, create a line plot representing the time series of transactions over the course of the year for each cardholder separately.
#
# * Next, to better compare their patterns, create a single line plot that containins both card holders' trend data.
#
# * What difference do you observe between the consumption patterns? Does the difference suggest a fraudulent transaction? Explain your rationale in the markdown report.

# %%
# Plot for cardholder 2
query = """
SELECT *
FROM transaction
WHERE card IN (SELECT card FROM credit_card WHERE cardholder_id = 2);
"""

# Execute the query and create a DataFrame from the fetched data
card_holder_2 = pd.read_sql_query(query, engine)

# Convert the 'date' column to pandas datetime
card_holder_2['date'] = pd.to_datetime(card_holder_2['date'])

# Generate the line plot for card holder 2
plot_card_holder_2 = card_holder_2.hvplot.line(x='date', y='amount', xlabel='Date', ylabel='Transaction Amount', title='Time Series of Transactions for Card Holder 2')

# Generate the hvplot for card holder 18
plot_card_holder_2
# Out:
# :Curve   [date]   (amount)

# %%
# loading data for card holder 2 and 18 from the database
# Write the query
query = """
        SELECT *
        FROM card_holder
        WHERE id IN (2, 18);
        """
# Create a DataFrame from the query result. HINT: Use pd.read_sql(query, engine)
query_df = pd.read_sql(query, engine)

query_df.head()
# Out:
#    id           name
# 0   2  Shane Shaffer
# 1  18  Malik Carlson

# %%
# Plot for cardholder 18
query = """
SELECT *
FROM transaction
WHERE card IN (SELECT card FROM credit_card WHERE cardholder_id = 18);
"""

# Execute the query and create a DataFrame from the fetched data
card_holder_18 = pd.read_sql_query(query, engine)

# Convert the 'date' column to pandas datetime
card_holder_18['date'] = pd.to_datetime(card_holder_18['date'])

# Generate the line plot for card holder 2
plot_card_holder_18 = card_holder_18.hvplot.line(x='date', y='amount', xlabel='Date', ylabel='Transaction Amount', title='Time Series of Transactions for Card Holder 18')

# Generate the hvplot for card holder 18
plot_card_holder_18
# Out:
# :Curve   [date]   (amount)

# %%
# Combined plot for card holders 2 and 18
plot_card_holder_18 * plot_card_holder_2
# Out:
# :Overlay
#    .Curve.I  :Curve   [date]   (amount)
#    .Curve.II :Curve   [date]   (amount)

# %% [markdown]
# ## Data Analysis Question 2
#
# The CEO of the biggest customer of the firm suspects that someone has used her corporate credit card without authorization in the first quarter of 2018 to pay quite expensive restaurant bills. Again, for privacy reasons, you know only that the cardholder ID in question is 25.
#
# * Using hvPlot, create a box plot, representing the expenditure data from January 2018 to June 2018 for cardholder ID 25.
#
# * Are there any outliers for cardholder ID 25? How many outliers are there per month?
#
# * Do you notice any anomalies? Describe your observations and conclusions in your markdown report.

# %%
# loading data of daily transactions from jan to jun 2018 for card holder 25
# Write the query
query = """
        SELECT * 
        FROM transaction
        WHERE card IN (SELECT card FROM credit_card WHERE cardholder_id = 25)
        AND date >= '2018-01-01' AND date < '2018-07-01';
        
        """
# Create a DataFrame from the query result. HINT: Use pd.read_sql(query, engine)
card_holder_25 = pd.read_sql(query, engine)
card_holder_25

box_plot = card_holder_25.hvplot.box(y='amount', by='date', width=1300, height=400, rot=60)

# Show the plot
box_plot
# Out:
# :BoxWhisker   [date]   (amount)

# %%
# loop to change the numeric month to month names
card_holder_25['date'] = pd.to_datetime(card_holder_25['date'])

# Extract the month names from the datetime objects
card_holder_25['month'] = card_holder_25['date'].dt.strftime('%B')

card_holder_25
# Out:
#       id                date   amount             card  id_merchant    month
# 0   2083 2018-01-02 02:06:21     1.46    4319653513507           93  January
# 1   1552 2018-01-05 06:26:45    10.74  372414832802279           86  January
# 2   2108 2018-01-07 14:57:23     2.93    4319653513507          137  January
# 3    754 2018-01-10 00:25:40     1.39  372414832802279           50  January
# 4   3023 2018-01-14 05:02:22    17.84  372414832802279           52  January
# ..   ...                 ...      ...              ...          ...      ...
# 63  2582 2018-06-22 06:16:50  1813.00    4319653513507           40     June
# 64  3218 2018-06-23 22:36:00    16.61    4319653513507          144     June
# 65  1523 2018-06-25 09:17:05    11.53  372414832802279           77     June
# 66  2264 2018-06-27 14:33:06     5.24  372414832802279           26     June
# 67   671 2018-06-30 03:05:55     2.27  372414832802279           87     June
#
# [68 rows x 6 columns]

# %%
# Creating the six box plots using hvPlot
# Create the box plot using hvplot with 'month' on the x-axis and 'amount' on the y-axis
box_plot = card_holder_25.hvplot.box(y='amount', by='month', width=1300, height=400, rot=60)

# Show the plot
box_plot
# Out:
# :BoxWhisker   [month]   (amount)
